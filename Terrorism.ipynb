# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install kaggle

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kanggle datasets list -s 'globalterrorismdb'
# Out:
# /bin/bash: line 1: kanggle: command not found

# %%
df = pd.read_csv('/content/globalterrorismdb_0718dist.csv', encoding='latin-1' or 'iso-8859-1' or 'cp1252')
# Try 'latin-1' encoding, which is a common alternative.
# If this doesn't work, you may need to experiment with other encodings like 'iso-8859-1' or 'cp1252'.
df
# Out:
# <ipython-input-23-15be5ebdca69>:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/globalterrorismdb_0718dist.csv', encoding='latin-1' or 'iso-8859-1' or 'cp1252')
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# ...
